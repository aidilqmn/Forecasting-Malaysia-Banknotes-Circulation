# %%
import holidays

my_holidays = holidays.MY(years=range(2026, 2031))

for date, name in sorted(my_holidays.items()):
    print(date, "->", name)
# Out:
# 2026-02-17 -> Tahun Baharu Cina
# 2026-02-18 -> Tahun Baharu Cina (Hari Kedua)
# 2026-03-21 -> Hari Raya Puasa
# 2026-03-22 -> Hari Raya Puasa (Hari Kedua)
# 2026-03-23 -> Cuti Hari Raya Puasa (Hari Kedua)
# 2026-05-01 -> Hari Pekerja
# 2026-05-27 -> Hari Raya Qurban
# 2026-05-31 -> Hari Wesak
# 2026-06-01 -> Hari Keputeraan Rasmi Seri Paduka Baginda Yang di-Pertuan Agong
# 2026-06-02 -> Cuti Hari Wesak
# 2026-06-17 -> Awal Muharam
# 2026-08-25 -> Hari Keputeraan Nabi Muhammad S.A.W.
# 2026-08-31 -> Hari Kebangsaan
# 2026-09-16 -> Hari Malaysia
# 2026-12-25 -> Hari Krismas
# 2027-02-06 -> Tahun Baharu Cina (anggaran)
# 2027-02-07 -> Tahun Baharu Cina (Hari Kedua) (anggaran)
# 2027-02-08 -> Cuti Tahun Baharu Cina (Hari Kedua) (anggaran)
# 2027-03-09 -> Hari Raya Puasa (anggaran)
# 2027-03-10 -> Hari Raya Puasa (Hari Kedua) (anggaran)
# 2027-05-01 -> Hari Pekerja
# 2027-05-16 -> Hari Raya Qurban (anggaran)
# 2027-05-17 -> Cuti Hari Raya Qurban (anggaran)
# ...
